# %%
import pandas as pd
import numpy as np
from IPython.display import Image
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
import re
import matplotlib.pyplot as plt

# %%
# !gdown 1POmzYEQZgZVqJO3F_cyNcd4QmoNE_mCv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1POmzYEQZgZVqJO3F_cyNcd4QmoNE_mCv
# To: c:\Users\VenkataKoushik\Desktop\Scaler\Lecture Notes\CV and NLP\Lecture_12\bbc-news-data.csv
#
#   0%|          | 0.00/5.08M [00:00<?, ?B/s]
#  21%|██        | 1.05M/5.08M [00:00<00:00, 6.06MB/s]
#  52%|█████▏    | 2.62M/5.08M [00:00<00:00, 9.22MB/s]
#  83%|████████▎ | 4.19M/5.08M [00:00<00:00, 10.9MB/s]
# 100%|██████████| 5.08M/5.08M [00:00<00:00, 10.1MB/s]

# %% [markdown]
# - Simple Neural network can't distinguish with different sequences
#
# - It treats "Man bites dog" and "dog biyes man" as same

# %% [markdown]
# # RNN

# %% [markdown]
# - Hidden layer is storing the history of previous step executed

# %% [markdown]
# ![image.png](attachment:image.png)
