# %% [markdown]
# - Word Cloud
# - Not that informative but easy to implement

# %% [markdown]
# ## LDA Algorithm

# %% [markdown]
# - Not a classification algortithm
# - It's a generative algorithm

# %% [markdown]
# - It is composed of two Dirichelete distrubution
# - Alpha and Beta are two parameters of dirichelete distribution

# %% [markdown]
# #### Maximum Likelyhood Estimation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Dirichelet Distribution

# %% [markdown]
# - A distribution of distributions

# %% [markdown]
# ![image.png](attachment:image.png)
