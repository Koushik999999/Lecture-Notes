# %%
import pandas as pd
import numpy as np
import string
import re
import random

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from gensim.models import word2vec, FastText
import gensim.downloader
from sklearn.decomposition import PCA

# %% [markdown]
# # Transformers

# %% [markdown]
# - ### Seq2Seq network
# - ### Statistical(Neural) Machine Translation
# - ### EncoderDecoder(RNNs)
# - ### Transformers
#     - #### Position Encoding
#     - #### Encoder
#     - #### Multi-headed Self Attention
#     - #### Decoder
#     - #### Feed Forward Network

# %% [markdown]
# - Issues with LSTMs
#
#     - Context vector becomes a bottleneck
#     - Vanishing/ Exploding Gradient
#     - Sequential Processing causes the LSTM to become slow

# %% [markdown]
# - Transformer does parrallel operation i.e process the entire sentence in on go

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Positional Encoding

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - The above is done in this part of the architecture:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Encoder Part

# %% [markdown]
# - Input to the encoder: ![image.png](attachment:image.png)

# %% [markdown]
# - 4 parts of the encoder:
# - ![image.png](attachment:image.png)

# %% [markdown]
# - ![image.png](attachment:image.png)

# %% [markdown]
# ## Decoder
