# %% [markdown]
# - xi is distance from x in higher dimension and xi' is distance from  x in lower dimension

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Probability in lower dimension should reflect the probability in higher dimension

# %% [markdown]
# - Probability values of both xi and xi' should be similar even though distance in lower dimensional space is high (why? , think about flattening a box(cubic) , (kooja to chambu (SNE))).

# %% [markdown]
# - When the graph is drwan to make it so,it is observed to be a t-distribution curve, hence the Qij formula below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Loss function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # PCA

# %% [markdown]
# ## Principle component Analysis

# %% [markdown]
# - Dimension reduction technique

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Both height and weight contribute significantly to the output here i.e both columns have highh variance
# - PCA creates two ore columns, i.e transforms these columns using vector addition/substraction , (not neccesarily h+w, h-w, it can also be 0.2 h + 0.5w(PCA will calculate this))
# - Now , in this case ,if variance of one of these two dimensions is low (i.e h+w or h-w), we can drop that column

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

# %% [markdown]
# - Sample code
# - ![image.png](attachment:image.png)

# %% [markdown]
# - PCA(2) means reduce it to two dimensions

# %% [markdown]
# # Mobile-Net

# %% [markdown]
# - No. of parameters are reduced using depthwise and pointwise convolutions

# %% [markdown]
# - ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
